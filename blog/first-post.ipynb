# %% [markdown]
#  My first post
#  --------------
#
# This is written in [IPython](http://ipython.org/install.html) [Notebook](http://ipython.org/notebook.html), using a Markdown cell. I don't know [Markdown](http://daringfireball.net/projects/markdown/syntax), but I guess I'll be getting to know it.
#
# I also want to try writing a post with Emacs org-mode, and compiling with emacs.
#
#  *  [Nikola plugin to compile org-mode pages](http://punchagan.muse-amuse.in/posts/blogging-with-nikola-and-org-mode.html)
#  * [nice emacs nikola publishing code](http://wikemacs.org/wiki/Nikola )
#  * [Nikola + ipython + github pages, slightly dated, but good info](http://brunettoziosi.eu/posts/blogging-with-nikola-ipython-github.html ) I followed his steps to get started with this post.
#
#  * [this guy blogs in ipython and makes a nice theme](http://www.damian.oquanta.info/posts/bidirectional-ipython-nikola-workflow-to-write-your-blog-post.html  )
#  * [the Nikola Handbook](http://nikola.readthedocs.org/en/latest/manual/ )
#  * [another way to host, with nikola on the server, building there](http://tinkeringwithstuff.com/posts/my-setup-for-blogging-with-nikola.html)
#
#  Notes
#  -------
#
#  *  It is handy to set all of this up in a [VirtualEnv](http://docs.python-guide.org/en/latest/dev/virtualenvs/) using [VirtualEnvWrapper](http://virtualenvwrapper.readthedocs.org/en/latest/index.html)
#  * ```nikola build``` didn't work very well without ***node.js***.  I Installed it from my distro's packages (just normal, not the ``-devel`` package, *but* it has to be 0.9.12 or later... e.g. openSUSE 12.3 has 0.8.12, so I needed to look in [software.opensuse.org](http://software.opensuse.org/package/nodejs) or else upgrade to oS 13.1)

# %%
7*6
# Out:
# 42

# %%
cd ~/Projects/blogs/net/
# Out:
# /home/mjl/Projects/blogs/net

# %%
ls -l
# Out:
# total 36
# drwxr-xr-x 1 mjl users    28 Aug 22 22:23 cache/
# -rw-r--r-- 1 mjl users 29390 Aug 22 08:54 conf.py
# -rw-r--r-- 1 mjl users  3292 Aug 22 21:53 conf.pyc
# drwxr-xr-x 1 mjl users    18 Aug 22 10:05 org/
# drwxr-xr-x 1 mjl users   182 Aug 22 22:23 output/
# drwxr-xr-x 1 mjl users    98 Aug 22 08:54 posts/
# drwxr-xr-x 1 mjl users    40 Aug 22 08:54 themes/

# %%
import sys

# %%
sys.path.append('/home/mjl/Projects/blogs/net/lib/')

# %%
# %load_ext pygments_magic

# %%
# %highlight -g light /home/mjl/Projects/blogs/net/conf.py
# Out:
# # -*- coding: utf-8 -*-
#
# from __future__ import unicode_literals
# import time
#
# # !! This is the configuration of Nikola. !! #
# # !!  You should edit it to your liking.  !! #
#
#
# # ! Some settings can be different in different languages.
# # ! A comment stating (translatable) is used to denote those.
# # ! There are two ways to specify a translatable setting:
# # ! (a) BLOG_TITLE = "My Blog"
# # ! (b) BLOG_TITLE = {"en": "My Blog", "es": "Mi Blog"}
# # ! Option (a) is used when you don't want that setting translated.
# # ! Option (b) is used for settings that are different in different languages.
#
#
# # Data about this site
# BLOG_AUTHOR = "Mike Lockhart"  # (translatable)
# BLOG_TITLE = "Milosophical Me"  # (translatable)
# # This is the main URL for your site. It will be used
# # in a prominent link
# SITE_URL = "http://milosophical.me/"
# # This is the URL where nikola's output will be deployed.
# # If not set, defaults to SITE_URL
# ...

# %%
# %highlight /home/mjl/.emacs.d/init.el
# Out:
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;
# ;;  File:       init.el
# ;;  Created:    2011-11-02
# ;;  Language:   Emacs-Lisp
# ;;  Time-stamp: <2014-07-11 09:31:32 mjl>
# ;;  Platform:   Emacs 24
# ;;  OS:         N/A
# ;;  Author:     [MJL] Michael J. Lockhart (sinewalker@gmail.com)
# ;;
# ;;  Rights:     Copyright Â© 2011-2014 Michael James Lockhart, B.App.Comp(HONS)
# ;;
# ;;  PURPOSE:    GNU Emacs Configuration
# ;;
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;
# ;;; Commentary:
# ;;
# ;;      This bootstraps my emacs customisations for Emacs 24. It is
# ;;      inspired by the Emacs Starter Kit version 2
# ;;      (http://github.com/technomancy/emacs-starter-kit), but I have
# ;;      since moved to rolling my own, per technomancy's
# ;;      recommendation.
# ;;
# ;;      This file does three things:
# ;;
# ;;        1. Initialise the ELPA with the Marmalade repository and
# ...
